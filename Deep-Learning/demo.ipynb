# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Generating random data

# %%
obs = 100000

xs = np.random.uniform(-10,10,(obs,1))
zs = np.random.uniform(-10,10,(obs,1))

# %%
inp = np.column_stack((xs,zs))
inp.shape
# Out:
# (100000, 2)

# %% [markdown]
# ## Target

# %%
noise = np.random.uniform(-1,1,(obs,1))

targets = 2*xs + 3*zs +5 + noise

targets.shape
# Out:
# (100000, 1)

# %% [markdown]
# ## Initialize Variables

# %%
init_range = 0.1

weights = np.random.uniform(-init_range,init_range,(2,1))
bias = np.random.uniform(-init_range,init_range,1)

# %% [markdown]
# ## Learning Rate

# %%
learning_rate = 1

# %% [markdown]
# ## Train The model

# %%
for i in range(100):
    output = np.dot(inp,weights) + bias

    delta = output - targets

    loss = np.sum(delta**2)/2/obs
    print(loss)

    delta_scaled = delta / obs
    weights = weights - learning_rate*np.dot(inp.T,delta_scaled)
    bias = bias - learning_rate*np.sum(delta_scaled)
# Out:
# 216.95609438652593
# 212291.51203694852
# 220658939.68245378
# 229356410238.92947
# 238396764431459.03
# 2.4779352151574534e+17
# 2.575607340154861e+20
# 2.6771300857977853e+23
# 2.7826552783487513e+26
# 2.892340730979214e+29
# 3.0063504798640673e+32
# 3.1248550295875167e+35
# 3.2480316082265703e+38
# 3.3760644324943917e+41
# 3.5091449833404828e+44
# 3.6474722924190387e+47
# 3.791253239855573e+50
# 3.940702863756127e+53
# 4.096044681923055e+56
# 4.2575110262578e+59
# 4.425343390352533e+62
# 4.599792790789115e+65
# 4.781120142687205e+68
# 4.969596650062811e+71
# 5.165504211581682e+74
# 5.369135842314963e+77
# 5.580796112127437e+80
# 5.800801601354771e+83
# 6.02948137445199e+86
# 6.267177472321426e+89
# 6.514245424056799e+92
# 6.771054778869654e+95
# 7.03798965899351e+98
# 7.315449334393675e+101
# 7.603848820142424e+104
# 7.903619497353327e+107
# 8.215209758603346e+110
# 8.539085678811097e+113
# 8.875731712570877e+116
# 9.225651418989529e+119
# 9.589368215109254e+122
# 9.967426159044426e+125
# 1.0360390764003295e+129
# 1.0768849844413758e+132
# 1.119341439541855e+135
# 1.1634719507055742e+138
# 1.2093425314495424e+141
# 1.257021798574849e+144
# 1.3065810748332144e+147
# 1.3580944956423885e+150
# 1.4116391200103495e+153
# 1.467295045834075e+156
# 1.5251455297455887e+159
# 1.585277111684532e+162
# 1.6477797443838222e+165
# 1.7127469279618867e+168
# 1.7802758498230451e+171
# 1.8504675300756134e+174
# 1.9234269726847132e+177
# 1.99926332258675e+180
# 2.0780900289999956e+183
# 2.160025015176178e+186
# 2.245190854846665e+189
# 2.3337149556276656e+192
# 2.425729749658558e+195
# 2.5213728917590507e+198
# 2.6207874654010635e+201
# 2.724122196804192e+204
# 2.8315316774749173e+207
# 2.9431765955223713e+210
# 3.059223976096984e+213
# 3.179847431312012e+216
# 3.3052274200214094e+219
# 3.43555151784349e+222
# 3.5710146978338154e+225
# 3.711819622227621e+228
# 3.858176945688422e+231
# 4.010305630516417e+234
# 4.168433274288483e+237
# 4.3327964504201074e+240
# 4.503641062158606e+243
# 4.681222710538145e+246
# 4.865807076845877e+249
# 5.0576703201727985e+252
# 5.2570994906438275e+255
# 5.4643929589449135e+258
# 5.679860862790841e+261
# 5.903825571001691e+264
# 6.136622165881514e+267
# 6.37859894462236e+270
# 6.630117940482969e+273
# 6.89155546452321e+276
# 7.16330266870319e+279
# 7.445766131191792e+282
# 7.739368464758733e+285
# 8.044548949161842e+288
# 8.361764188475231e+291
# 8.691488794342167e+294
# 9.034216096175406e+297
# 9.390458879367597e+300

# %%
plt.plot(targets.flatten(),output.flatten())
